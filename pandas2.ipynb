# %% [markdown]
# # Pandas

# %%
#importing pandas to use in python notebook
import pandas as pd

# %%
#reading a csv file from local storage
df = pd.read_csv('housing.csv')

# %%
#dataframe output
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#get columns using loc
df.loc[:, ['bathrooms', 'bedrooms']]
# Out:
#      bathrooms  bedrooms
# 0            2         4
# 1            4         4
# 2            2         3
# 3            2         4
# 4            1         4
# ..         ...       ...
# 540          1         2
# 541          1         3
# 542          1         2
# 543          1         3
# 544          1         3
#
# [545 rows x 2 columns]

# %%
#get columns using iloc
df.iloc[:, [2,3]]
# Out:
#      bedrooms  bathrooms
# 0           4          2
# 1           4          4
# 2           3          2
# 3           4          2
# 4           4          1
# ..        ...        ...
# 540         2          1
# 541         3          1
# 542         2          1
# 543         3          1
# 544         3          1
#
# [545 rows x 2 columns]

# %%
#first five rows of the dataset
df.head(7)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
# 5  10850000  7500         3          3        1      yes        no      yes
# 6  10150000  8580         4          3        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# ...

# %%
#gives the dimension of the dataset
df.shape
# Out:
# (545, 13)

# %%
#brief statistical description of the dataset
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
#information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
#drop certain columns in the dataset
df.drop(columns = ['mainroad', 'guestroom'])
# Out:
#         price  area  bedrooms  bathrooms  stories basement hotwaterheating  \
# 0    13300000  7420         4          2        3       no              no
# 1    12250000  8960         4          4        4       no              no
# 2    12250000  9960         3          2        2      yes              no
# 3    12215000  7500         4          2        2      yes              no
# 4    11410000  7420         4          1        2      yes              no
# ..        ...   ...       ...        ...      ...      ...             ...
# 540   1820000  3000         2          1        1      yes              no
# 541   1767150  2400         3          1        1       no              no
# 542   1750000  3620         2          1        1       no              no
# 543   1750000  2910         3          1        1       no              no
# 544   1750000  3850         3          1        2       no              no
#
#     airconditioning  parking prefarea furnishingstatus
# ...

# %%
#grouping columns by groupby
df.groupby('furnishingstatus').count()
# Out:
#                   price  area  bedrooms  bathrooms  stories  mainroad  \
# furnishingstatus
# furnished           140   140       140        140      140       140
# semi-furnished      227   227       227        227      227       227
# unfurnished         178   178       178        178      178       178
#
#                   guestroom  basement  hotwaterheating  airconditioning  \
# furnishingstatus
# furnished               140       140              140              140
# semi-furnished          227       227              227              227
# unfurnished             178       178              178              178
#
#                   parking  prefarea
# furnishingstatus
# furnished             140       140
# semi-furnished        227       227
# unfurnished           178       178

# %%
#dropping null values
df.dropna()
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#applying a function on a dataframe

# %% [markdown]
# # Matplotlib

# %%
#importing matplotlib into python

# %%
#basic scatterplot
x = [1, 2, 3, 4, 5, 6, 7]
y = [50, 49, 48, 47, 52, 50, 49]

# %%
#multiple plots on the same graph
x = [1, 2, 3, 4, 5, 6, 7]
y1 = [50, 49, 48, 47, 52, 50, 49]
y2 = [49, 50, 48, 48, 53, 51, 47]

#plotting both y1 and y2

#adding xlabel, ylabel and title

#adding legend

# %%
#horizontal bar graph using barh
x = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
y1 = [50, 49, 48, 47, 52, 50, 49]

# %%
#histogram - single variable
bsm = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 89]

# %%
#histogram - two variables
bsm = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 89]
bsw = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
